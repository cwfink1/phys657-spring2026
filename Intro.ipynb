# %% [markdown]
# # Welcome to Phys 657 Spring 2026
# M/W 2:15pm-3:35pm, phys204
#
# Instructor: Caleb Fink, cwfink@syr.edu
#
# Office:phys 219

# %% [markdown]
# ### Assignments
#
# In this calss we will have two deliverables:
#
# * Coding projects to be done in class with partners
# * Writeups of in class coding projects

# %% [markdown]
# ### Turning in assignments
# * Writeups are to be printed at turned in at the beginning of class - I am open to the idea of having writeups turned in electronically, we will discuss as a class
#
# * coding projects are to be done in python using jupyter notebooks and uploaded to the class [github](https://github.com/cwfink1/phys657-spring2026#)
#   * if not already done, a python distribution should be installed, e.g. [miniconda](https://www.anaconda.com/docs/getting-started/miniconda/main), as well as [git](https://git-scm.com/book/en/v2/Getting-Started-Installing-Git)

# %% [markdown]
# ### setting up github
#
# the class repository can be found here: https://github.com/cwfink1/phys657-spring2026#
#
# * Please create a github account if you do not already have one
# * you will need to setup SSH keys in order to connect to the repo, the instructions are shown below:
#
#
# ![Screenshot 2026-01-10 at 5.02.23 PM.png](attachment:679be190-7ec7-47aa-9e1d-67aa4bba3063.png)
# ![Screenshot 2026-01-10 at 5.03.14 PM.png](attachment:dc6135b5-6661-4129-85d8-ca7e2196b8f9.png)
# ![Screenshot 2026-01-10 at 5.03.28 PM.png](attachment:882c4cda-3ad9-44a5-a3b7-ec22de9262eb.png)

# %% [markdown]
# ## Create your own branch where you will turn in assignments

# %% [markdown]
# First, you must close the repo:
#
# ```
# git clone git@github.com:cwfink1/phys657-spring2026.git'''

# %% [markdown]
#  Make your own brach for your group (only one notebook is required per pair).
# ```
# git checkout -b <branch-name>

# %% [markdown]
# work in this branch. When you are ready to submit your work:
#
# Add your changes and include a commit message that indidcates which module this is for
#
# ```
# git add .
# git commit -m "Your commit message"

# %% [markdown]
# Last, push your work to your branch
#
# ```
# git push -u origin <branch-name>
